# %% [markdown]
# # Aqui trabajamos con https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import matplotlib as plt

import seaborn as sns

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
chronic_kidney_disease = fetch_ucirepo(id=336)

# data (as pandas dataframes)
X = chronic_kidney_disease.data.features
y = chronic_kidney_disease.data.targets

# metadata
print(chronic_kidney_disease.metadata)

# variable information
print(chronic_kidney_disease.variables)
# Out:
# {'uci_id': 336, 'name': 'Chronic Kidney Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/336/data.csv', 'abstract': 'This dataset can be used to predict the chronic kidney disease and it can be collected from the hospital nearly 2 months of period.', 'area': 'Other', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 400, 'num_features': 24, 'feature_types': ['Real'], 'demographics': ['Age'], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 2015, 'last_updated': 'Mon Mar 04 2024', 'dataset_doi': '10.24432/C5G020', 'creators': ['L. Rubini', 'P. Soundarapandian', 'P. Eswaran'], 'intro_paper': None, 'additional_info': {'summary': 'We use the following representation to collect the dataset\r\n                        age\t\t-\tage\t\r\n\t\t\tbp\t\t-\tblood pressure\r\n\t\t\tsg
# ...

# %%
import pandas as pd

# Combinar features y target en un solo DataFrame
df = pd.concat([X, y], axis=1)

# Guardar como CSV
df.to_csv("chronic_kidney_disease.csv", index=False)

print("Dataset guardado como chronic_kidney_disease.csv")
# Out:
# Dataset guardado como chronic_kidney_disease.csv

# %%
# Cargar el archivo CSV en Kidney1
Kidney1 = pd.read_csv("chronic_kidney_disease.csv")

# %%
# Contar cuántas filas duplicadas hay
print("Número de duplicados:", Kidney1.duplicated().sum())
# Out:
# Número de duplicados: 0

# %%
Kidney1.shape
# Out:
# (400, 25)

# %% [markdown]
# Trabajamos los datos faltantes

# %%
Kidney1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     391 non-null    float64
#  1   bp      388 non-null    float64
#  2   sg      353 non-null    float64
#  3   al      354 non-null    float64
#  4   su      351 non-null    float64
#  5   rbc     248 non-null    object
#  6   pc      335 non-null    object
#  7   pcc     396 non-null    object
#  8   ba      396 non-null    object
#  9   bgr     356 non-null    float64
#  10  bu      381 non-null    float64
#  11  sc      383 non-null    float64
#  12  sod     313 non-null    float64
#  13  pot     312 non-null    float64
#  14  hemo    348 non-null    float64
#  15  pcv     329 non-null    float64
#  16  wbcc    294 non-null    float64
#  17  rbcc    269 non-null    float64
#  18  htn     398 non-null    object
#  19  dm      398 non-null    object
#  20  cad     398 non-null    object
# ...

# %%
import pandas as pd

# Crear columna indicadora de valores faltantes en age
Kidney1["age_missing"] = Kidney1["age"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["age", "age_missing"]].head(10))
# Out:
#     age  age_missing
# 0  48.0            0
# 1   7.0            0
# 2  62.0            0
# 3  48.0            0
# 4  51.0            0
# 5  60.0            0
# 6  68.0            0
# 7  24.0            0
# 8  52.0            0
# 9  53.0            0

# %%
# Crear columna indicadora de valores faltantes en bp
Kidney1["bp_missing"] = Kidney1["bp"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["bp", "bp_missing"]].head(10))
# Out:
#       bp  bp_missing
# 0   80.0           0
# 1   50.0           0
# 2   80.0           0
# 3   70.0           0
# 4   80.0           0
# 5   90.0           0
# 6   70.0           0
# 7    NaN           1
# 8  100.0           0
# 9   90.0           0

# %%
# Crear columna indicadora de valores faltantes en sg
Kidney1["sg_missing"] = Kidney1["sg"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["sg", "sg_missing"]].head(10))
# Out:
#       sg  sg_missing
# 0  1.020           0
# 1  1.020           0
# 2  1.010           0
# 3  1.005           0
# 4  1.010           0
# 5  1.015           0
# 6  1.010           0
# 7  1.015           0
# 8  1.015           0
# 9  1.020           0

# %%
# Crear columna indicadora de valores faltantes en al
Kidney1["al_missing"] = Kidney1["al"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["al", "al_missing"]].head(10))
# Out:
#     al  al_missing
# 0  1.0           0
# 1  4.0           0
# 2  2.0           0
# 3  4.0           0
# 4  2.0           0
# 5  3.0           0
# 6  0.0           0
# 7  2.0           0
# 8  3.0           0
# 9  2.0           0

# %%
# Crear columna indicadora de valores faltantes en al
Kidney1["su_missing"] = Kidney1["su"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["su", "su_missing"]].head(10))
# Out:
#     su  su_missing
# 0  0.0           0
# 1  0.0           0
# 2  3.0           0
# 3  0.0           0
# 4  0.0           0
# 5  0.0           0
# 6  0.0           0
# 7  4.0           0
# 8  0.0           0
# 9  0.0           0

# %%
import pandas as pd

# Definir las columnas a procesar
cols = ["rbc", "pc"]

for col in cols:
    # Columna indicadora de valores faltantes
    Kidney1[f"{col}_missing"] = Kidney1[col].isnull().astype(int)

    # Normalización: normal = 0, abnormal = 1
    Kidney1[f"{col}_norm"] = Kidney1[col].map({"normal": 0, "abnormal": 1})

    # Si hay NaN, se mantienen como NaN en la columna normalizada

# Verificar resultado
print(Kidney1[["rbc", "rbc_missing", "rbc_norm"]].head(10))
print(Kidney1[["pc", "pc_missing", "pc_norm"]].head(10))
# Out:
#         rbc  rbc_missing  rbc_norm
# 0       NaN            1       NaN
# 1       NaN            1       NaN
# 2    normal            0       0.0
# 3    normal            0       0.0
# 4    normal            0       0.0
# 5       NaN            1       NaN
# 6       NaN            1       NaN
# 7    normal            0       0.0
# 8    normal            0       0.0
# 9  abnormal            0       1.0
#          pc  pc_missing  pc_norm
# 0    normal           0      0.0
# 1    normal           0      0.0
# 2    normal           0      0.0
# 3  abnormal           0      1.0
# 4    normal           0      0.0
# 5       NaN           1      NaN
# 6    normal           0      0.0
# 7  abnormal           0      1.0
# 8  abnormal           0      1.0
# 9  abnormal           0      1.0

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["pcc"].unique())
# Out:
# ['notpresent' 'present' nan]

# %%
# Crear columna indicadora de valores faltantes en pcc
Kidney1["pcc_missing"] = Kidney1["pcc"].isnull().astype(int)

# Normalización: notpresent = 0, present = 1
Kidney1["pcc_norm"] = Kidney1["pcc"].map({"notpresent": 0, "present": 1})

# Eliminar la columna original pcc
Kidney1 = Kidney1.drop(columns=["pcc"])

# Verificar resultado
print(Kidney1[["pcc_missing", "pcc_norm"]].head(10))
# Out:
#    pcc_missing  pcc_norm
# 0            0       0.0
# 1            0       0.0
# 2            0       0.0
# 3            0       1.0
# 4            0       0.0
# 5            0       0.0
# 6            0       0.0
# 7            0       0.0
# 8            0       1.0
# 9            0       1.0

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["ba"].unique())
# Out:
# ['notpresent' 'present' nan]

# %%
# Columna indicadora de valores faltantes en ba
Kidney1["ba_missing"] = Kidney1["ba"].isnull().astype(int)

# Normalización: notpresent = 0, present = 1
Kidney1["ba_norm"] = Kidney1["ba"].map({"notpresent": 0, "present": 1})

# Eliminar la columna original ba
Kidney1 = Kidney1.drop(columns=["ba"])

# Verificar resultado
print(Kidney1[["ba_missing", "ba_norm"]].head(10))
# Out:
#    ba_missing  ba_norm
# 0           0      0.0
# 1           0      0.0
# 2           0      0.0
# 3           0      0.0
# 4           0      0.0
# 5           0      0.0
# 6           0      0.0
# 7           0      0.0
# 8           0      0.0
# 9           0      0.0

# %%
# Crear columna indicadora de valores faltantes en bgr
Kidney1["bgr_missing"] = Kidney1["bgr"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["bgr", "bgr_missing"]].head(10))
# Out:
#      bgr  bgr_missing
# 0  121.0            0
# 1    NaN            1
# 2  423.0            0
# 3  117.0            0
# 4  106.0            0
# 5   74.0            0
# 6  100.0            0
# 7  410.0            0
# 8  138.0            0
# 9   70.0            0

# %%
# Columna indicadora de valores faltantes en bu
Kidney1["bu_missing"] = Kidney1["bu"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["bu", "bu_missing"]].head(10))
# Out:
#       bu  bu_missing
# 0   36.0           0
# 1   18.0           0
# 2   53.0           0
# 3   56.0           0
# 4   26.0           0
# 5   25.0           0
# 6   54.0           0
# 7   31.0           0
# 8   60.0           0
# 9  107.0           0

# %%
# Columna indicadora de valores faltantes en sc
Kidney1["sc_missing"] = Kidney1["sc"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["sc", "sc_missing"]].head(10))
# Out:
#      sc  sc_missing
# 0   1.2           0
# 1   0.8           0
# 2   1.8           0
# 3   3.8           0
# 4   1.4           0
# 5   1.1           0
# 6  24.0           0
# 7   1.1           0
# 8   1.9           0
# 9   7.2           0

# %%
# Columna indicadora de valores faltantes en sod
Kidney1["sod_missing"] = Kidney1["sod"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["sod", "sod_missing"]].head(10))
# Out:
#      sod  sod_missing
# 0    NaN            1
# 1    NaN            1
# 2    NaN            1
# 3  111.0            0
# 4    NaN            1
# 5  142.0            0
# 6  104.0            0
# 7    NaN            1
# 8    NaN            1
# 9  114.0            0

# %%
# Columna indicadora de valores faltantes en pot
Kidney1["pot_missing"] = Kidney1["pot"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["pot", "pot_missing"]].head(10))
# Out:
#    pot  pot_missing
# 0  NaN            1
# 1  NaN            1
# 2  NaN            1
# 3  2.5            0
# 4  NaN            1
# 5  3.2            0
# 6  4.0            0
# 7  NaN            1
# 8  NaN            1
# 9  3.7            0

# %%
# Columna indicadora de valores faltantes en hemo
Kidney1["hemo_missing"] = Kidney1["hemo"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["hemo", "hemo_missing"]].head(10))
# Out:
#    hemo  hemo_missing
# 0  15.4             0
# 1  11.3             0
# 2   9.6             0
# 3  11.2             0
# 4  11.6             0
# 5  12.2             0
# 6  12.4             0
# 7  12.4             0
# 8  10.8             0
# 9   9.5             0

# %%
# Columna indicadora de valores faltantes en pcv
Kidney1["pcv_missing"] = Kidney1["pcv"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["pcv", "pcv_missing"]].head(10))
# Out:
#     pcv  pcv_missing
# 0  44.0            0
# 1  38.0            0
# 2  31.0            0
# 3  32.0            0
# 4  35.0            0
# 5  39.0            0
# 6  36.0            0
# 7  44.0            0
# 8  33.0            0
# 9  29.0            0

# %%
# Columna indicadora de valores faltantes en wbcc
Kidney1["wbcc_missing"] = Kidney1["wbcc"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["wbcc", "wbcc_missing"]].head(10))
# Out:
#       wbcc  wbcc_missing
# 0   7800.0             0
# 1   6000.0             0
# 2   7500.0             0
# 3   6700.0             0
# 4   7300.0             0
# 5   7800.0             0
# 6      NaN             1
# 7   6900.0             0
# 8   9600.0             0
# 9  12100.0             0

# %%
# Columna indicadora de valores faltantes en rbcc
Kidney1["rbcc_missing"] = Kidney1["rbcc"].isnull().astype(int)

# Verificar resultado
print(Kidney1[["rbcc", "rbcc_missing"]].head(10))
# Out:
#    rbcc  rbcc_missing
# 0   5.2             0
# 1   NaN             1
# 2   NaN             1
# 3   3.9             0
# 4   4.6             0
# 5   4.4             0
# 6   NaN             1
# 7   5.0             0
# 8   4.0             0
# 9   3.7             0

# %%
# Imputar valores faltantes en htn con la moda
Kidney1["htn"].fillna(Kidney1["htn"].mode()[0], inplace=True)

# Verificar resultado
print(Kidney1["htn"].value_counts(dropna=False))
# Out:
# htn
# no     253
# yes    147
# Name: count, dtype: int64
# /tmp/ipykernel_1947/1948599622.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Kidney1["htn"].fillna(Kidney1["htn"].mode()[0], inplace=True)

# %%
# Imputar valores faltantes en dm con la moda
Kidney1["dm"].fillna(Kidney1["dm"].mode()[0], inplace=True)

# Verificar resultado
print(Kidney1["dm"].value_counts(dropna=False))
# Out:
# dm
# no      262
# yes     137
# \tno      1
# Name: count, dtype: int64
# /tmp/ipykernel_1947/1773807344.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Kidney1["dm"].fillna(Kidney1["dm"].mode()[0], inplace=True)

# %%
# Imputar valores faltantes en cad con la moda
Kidney1["cad"].fillna(Kidney1["cad"].mode()[0], inplace=True)

# Verificar resultado
print(Kidney1["cad"].value_counts(dropna=False))
# Out:
# cad
# no     366
# yes     34
# Name: count, dtype: int64
# /tmp/ipykernel_1947/1948954724.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Kidney1["cad"].fillna(Kidney1["cad"].mode()[0], inplace=True)

# %%
# Imputar valores faltantes en appet con la moda
Kidney1["appet"].fillna(Kidney1["appet"].mode()[0], inplace=True)

# Verificar resultado
print(Kidney1["appet"].value_counts(dropna=False))
# Out:
# appet
# good    318
# poor     82
# Name: count, dtype: int64
# /tmp/ipykernel_1947/3429223820.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Kidney1["appet"].fillna(Kidney1["appet"].mode()[0], inplace=True)

# %%
# Imputar valores faltantes en pe con la moda
Kidney1["pe"].fillna(Kidney1["pe"].mode()[0], inplace=True)

# Verificar resultado
print(Kidney1["pe"].value_counts(dropna=False))
# Out:
# pe
# no     324
# yes     76
# Name: count, dtype: int64
# /tmp/ipykernel_1947/804626543.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Kidney1["pe"].fillna(Kidney1["pe"].mode()[0], inplace=True)

# %%
# Imputar valores faltantes en ane con la moda
Kidney1["ane"].fillna(Kidney1["ane"].mode()[0], inplace=True)

# Verificar resultado
print(Kidney1["ane"].value_counts(dropna=False))
# Out:
# ane
# no     340
# yes     60
# Name: count, dtype: int64
# /tmp/ipykernel_1947/2328341970.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Kidney1["ane"].fillna(Kidney1["ane"].mode()[0], inplace=True)

# %%
Kidney1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 45 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           391 non-null    float64
#  1   bp            388 non-null    float64
#  2   sg            353 non-null    float64
#  3   al            354 non-null    float64
#  4   su            351 non-null    float64
#  5   rbc           248 non-null    object
#  6   pc            335 non-null    object
#  7   bgr           356 non-null    float64
#  8   bu            381 non-null    float64
#  9   sc            383 non-null    float64
#  10  sod           313 non-null    float64
#  11  pot           312 non-null    float64
#  12  hemo          348 non-null    float64
#  13  pcv           329 non-null    float64
#  14  wbcc          294 non-null    float64
#  15  rbcc          269 non-null    float64
#  16  htn           400 non-null    object
# ...

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["rbc"].unique())
# Out:
# [nan 'normal' 'abnormal']

# %%
# Normalización de rbc: normal = 0, abnormal = 1
Kidney1["rbc_norm"] = Kidney1["rbc"].map({"normal": 0, "abnormal": 1})

# Verificar resultado
print(Kidney1[["rbc", "rbc_missing", "rbc_norm"]].head(10))
# Out:
#         rbc  rbc_missing  rbc_norm
# 0       NaN            1       NaN
# 1       NaN            1       NaN
# 2    normal            0       0.0
# 3    normal            0       0.0
# 4    normal            0       0.0
# 5       NaN            1       NaN
# 6       NaN            1       NaN
# 7    normal            0       0.0
# 8    normal            0       0.0
# 9  abnormal            0       1.0

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["pc"].unique())
# Out:
# ['normal' 'abnormal' nan]

# %%
# Normalización de pc: normal = 0, abnormal = 1
Kidney1["pc_norm"] = Kidney1["pc"].map({"normal": 0, "abnormal": 1})

# Verificar resultado
print(Kidney1[["pc", "pc_missing", "pc_norm"]].head(10))
# Out:
#          pc  pc_missing  pc_norm
# 0    normal           0      0.0
# 1    normal           0      0.0
# 2    normal           0      0.0
# 3  abnormal           0      1.0
# 4    normal           0      0.0
# 5       NaN           1      NaN
# 6    normal           0      0.0
# 7  abnormal           0      1.0
# 8  abnormal           0      1.0
# 9  abnormal           0      1.0

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["htn"].unique())
# Out:
# ['yes' 'no']

# %%
# Normalización de htn: no = 0, yes = 1
Kidney1["htn_norm"] = Kidney1["htn"].map({"no": 0, "yes": 1})

# Verificar resultado
print(Kidney1[["htn", "htn_norm"]].head(10))
# Out:
#    htn  htn_norm
# 0  yes         1
# 1   no         0
# 2   no         0
# 3  yes         1
# 4   no         0
# 5  yes         1
# 6   no         0
# 7   no         0
# 8  yes         1
# 9  yes         1

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["dm"].unique())
# Out:
# ['yes' 'no' '\tno']

# %%
# Limpieza de valores en dm (eliminar espacios/tabuladores)
Kidney1["dm"] = Kidney1["dm"].str.strip()

# Normalización de dm: no = 0, yes = 1
Kidney1["dm_norm"] = Kidney1["dm"].map({"no": 0, "yes": 1})

# Verificar resultado
print(Kidney1[["dm", "dm_norm"]].head(10))
# Out:
#     dm  dm_norm
# 0  yes        1
# 1   no        0
# 2  yes        1
# 3   no        0
# 4   no        0
# 5  yes        1
# 6   no        0
# 7  yes        1
# 8  yes        1
# 9  yes        1

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["cad"].unique())
# Out:
# ['no' 'yes']

# %%
# Normalización de cad: no = 0, yes = 1
Kidney1["cad_norm"] = Kidney1["cad"].map({"no": 0, "yes": 1})

# Verificar resultado
print(Kidney1[["cad", "cad_norm"]].head(10))
# Out:
#   cad  cad_norm
# 0  no         0
# 1  no         0
# 2  no         0
# 3  no         0
# 4  no         0
# 5  no         0
# 6  no         0
# 7  no         0
# 8  no         0
# 9  no         0

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["appet"].unique())
# Out:
# ['good' 'poor']

# %%
# Normalización de appet: good = 1, poor = 0
Kidney1["appet_norm"] = Kidney1["appet"].map({"poor": 0, "good": 1})

# Verificar resultado
print(Kidney1[["appet", "appet_norm"]].head(10))
# Out:
#   appet  appet_norm
# 0  good           1
# 1  good           1
# 2  poor           0
# 3  poor           0
# 4  good           1
# 5  good           1
# 6  good           1
# 7  good           1
# 8  good           1
# 9  poor           0

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["pe"].unique())
# Out:
# ['no' 'yes']

# %%
# Normalización de pe: no = 0, yes = 1
Kidney1["pe_norm"] = Kidney1["pe"].map({"no": 0, "yes": 1})

# Verificar resultado
print(Kidney1[["pe", "pe_norm"]].head(10))
# Out:
#     pe  pe_norm
# 0   no        0
# 1   no        0
# 2   no        0
# 3  yes        1
# 4   no        0
# 5  yes        1
# 6   no        0
# 7  yes        1
# 8   no        0
# 9   no        0

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["pe"].unique())
# Out:
# ['no' 'yes']

# %%
# Normalización de ane: no = 0, yes = 1
Kidney1["ane_norm"] = Kidney1["ane"].map({"no": 0, "yes": 1})

# Verificar resultado
print(Kidney1[["ane", "ane_norm"]].head(10))
# Out:
#    ane  ane_norm
# 0   no         0
# 1   no         0
# 2  yes         1
# 3  yes         1
# 4   no         0
# 5   no         0
# 6   no         0
# 7   no         0
# 8  yes         1
# 9  yes         1

# %%
# Valores únicos en la columna 'COPDSEVERITY'
print(Kidney1["class"].unique())
# Out:
# ['ckd' 'ckd\t' 'notckd']

# %%
# Limpieza de valores en class (eliminar espacios/tabuladores)
Kidney1["class"] = Kidney1["class"].str.strip()

# Normalización de class: notckd = 0, ckd = 1
Kidney1["class_norm"] = Kidney1["class"].map({"notckd": 0, "ckd": 1})

# Verificar resultado
print(Kidney1[["class", "class_norm"]].head(10))
# Out:
#   class  class_norm
# 0   ckd           1
# 1   ckd           1
# 2   ckd           1
# 3   ckd           1
# 4   ckd           1
# 5   ckd           1
# 6   ckd           1
# 7   ckd           1
# 8   ckd           1
# 9   ckd           1

# %%
Kidney1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 52 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           391 non-null    float64
#  1   bp            388 non-null    float64
#  2   sg            353 non-null    float64
#  3   al            354 non-null    float64
#  4   su            351 non-null    float64
#  5   rbc           248 non-null    object
#  6   pc            335 non-null    object
#  7   bgr           356 non-null    float64
#  8   bu            381 non-null    float64
#  9   sc            383 non-null    float64
#  10  sod           313 non-null    float64
#  11  pot           312 non-null    float64
#  12  hemo          348 non-null    float64
#  13  pcv           329 non-null    float64
#  14  wbcc          294 non-null    float64
#  15  rbcc          269 non-null    float64
#  16  htn           400 non-null    object
# ...

# %%
# Lista de columnas originales a eliminar
cols_to_drop = ["rbc", "pc", "htn", "dm", "cad", "appet", "pe", "ane", "class"]

# Eliminar columnas originales y quedarte solo con las normalizadas
Kidney1.drop(columns=cols_to_drop, inplace=True)

# Verificar columnas restantes
print(Kidney1.columns)
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo',
#        'pcv', 'wbcc', 'rbcc', 'age_missing', 'bp_missing', 'sg_missing',
#        'al_missing', 'su_missing', 'rbc_missing', 'rbc_norm', 'pc_missing',
#        'pc_norm', 'pcc_missing', 'pcc_norm', 'ba_missing', 'ba_norm',
#        'bgr_missing', 'bu_missing', 'sc_missing', 'sod_missing', 'pot_missing',
#        'hemo_missing', 'pcv_missing', 'wbcc_missing', 'rbcc_missing',
#        'htn_norm', 'dm_norm', 'cad_norm', 'appet_norm', 'pe_norm', 'ane_norm',
#        'class_norm'],
#       dtype='object')

# %%
Kidney1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 43 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           391 non-null    float64
#  1   bp            388 non-null    float64
#  2   sg            353 non-null    float64
#  3   al            354 non-null    float64
#  4   su            351 non-null    float64
#  5   bgr           356 non-null    float64
#  6   bu            381 non-null    float64
#  7   sc            383 non-null    float64
#  8   sod           313 non-null    float64
#  9   pot           312 non-null    float64
#  10  hemo          348 non-null    float64
#  11  pcv           329 non-null    float64
#  12  wbcc          294 non-null    float64
#  13  rbcc          269 non-null    float64
#  14  age_missing   400 non-null    int64
#  15  bp_missing    400 non-null    int64
#  16  sg_missing    400 non-null    int64
#  17  al_missing    400 non-null    int64
# ...

# %%
# Guardar Pulmo1 en un archivo CSV
Kidney1.to_csv("Kidney1.csv", index=False)

print("Archivo Kidney1.csv descargado correctamente")
# Out:
# Archivo Kidney1.csv descargado correctamente

# %%
import pandas as pd

# Diccionario con la descripción de las variables
descripcion = {
    "Columna": [
        "age", "bp", "sg", "al", "su",
        "rbc", "pc", "pcc", "ba", "bgr",
        "bu", "sc", "sod", "pot", "hemo",
        "pcv", "wbcc", "rbcc", "htn", "dm",
        "cad", "appet", "pe", "ane", "class"
    ],
    "Tipo de Dato": [
        "float64", "float64", "float64", "float64", "float64",
        "object", "object", "object", "object", "float64",
        "float64", "float64", "float64", "float64", "float64",
        "float64", "float64", "float64", "object", "object",
        "object", "object", "object", "object", "object"
    ],
    "Descripción": [
        "Edad del paciente",
        "Presión arterial",
        "Gravedad específica de la orina",
        "Nivel de albúmina en orina",
        "Nivel de azúcar en orina",
        "Glóbulos rojos (normal/anormal)",
        "Células epiteliales (normal/anormal)",
        "Presencia de células patológicas",
        "Presencia de bacterias",
        "Glucosa en sangre",
        "Urea en sangre",
        "Creatinina sérica",
        "Sodio en sangre",
        "Potasio en sangre",
        "Hemoglobina",
        "Volumen de células empaquetadas (hematocrito)",
        "Conteo de glóbulos blancos",
        "Conteo de glóbulos rojos",
        "Hipertensión (sí/no)",
        "Diabetes mellitus (sí/no)",
        "Enfermedad coronaria (sí/no)",
        "Apetito (bueno/pobre)",
        "Edema pedal (sí/no)",
        "Anemia (sí/no)",
        "Clase: enfermedad renal crónica o normal"
    ]
}

# Crear DataFrame descriptivo
tabla_vars = pd.DataFrame(descripcion)

# Mostrar tabla
print(tabla_vars)
# Out:
#    Columna Tipo de Dato                                    Descripción
# 0      age      float64                              Edad del paciente
# 1       bp      float64                               Presión arterial
# 2       sg      float64                Gravedad específica de la orina
# 3       al      float64                     Nivel de albúmina en orina
# 4       su      float64                       Nivel de azúcar en orina
# 5      rbc       object                Glóbulos rojos (normal/anormal)
# 6       pc       object           Células epiteliales (normal/anormal)
# 7      pcc       object               Presencia de células patológicas
# 8       ba       object                         Presencia de bacterias
# 9      bgr      float64                              Glucosa en sangre
# 10      bu      float64                                 Urea en sangre
# 11      sc      float64                              Creatinina sérica
# ...
