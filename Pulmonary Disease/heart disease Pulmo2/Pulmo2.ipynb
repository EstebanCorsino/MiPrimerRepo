# %% [markdown]
# # Aqui trabajamos con https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import matplotlib as plt

import seaborn as sns

# %%
# cargar la base de datos
Pulmo2 = pd.read_csv("heart_disease_combined.csv")

# %%
Pulmo2.shape
# Out:
# (246022, 40)

# %%
Pulmo2.isnull().sum()
# Out:
# State                        0
# Sex                          0
# GeneralHealth                0
# PhysicalHealthDays           0
# MentalHealthDays             0
# LastCheckupTime              0
# PhysicalActivities           0
# SleepHours                   0
# RemovedTeeth                 0
# HadHeartAttack               0
# HadAngina                    0
# HadStroke                    0
# HadAsthma                    0
# HadSkinCancer                0
# HadCOPD                      0
# HadDepressiveDisorder        0
# HadKidneyDisease             0
# HadArthritis                 0
# HadDiabetes                  0
# DeafOrHardOfHearing          0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DifficultyWalking            0
# DifficultyDressingBathing    0
# DifficultyErrands            0
# SmokerStatus                 0
# ECigaretteUsage              0
# ChestScan                    0
# RaceEthnicityCategory        0
# AgeCategory                  0
# ...

# %% [markdown]
# Vemos si hay duplicados

# %%
# Contar cuántas filas duplicadas hay
print("Número de duplicados:", Pulmo2.duplicated().sum())
# Out:
# Número de duplicados: 9

# %% [markdown]
# Eliminamos duplicados

# %%
# Eliminar filas duplicadas y quedarte con la primera ocurrencia
Pulmo2 = Pulmo2.drop_duplicates()

# Verificar nuevamente
print("Número de duplicados después de limpiar:", Pulmo2.duplicated().sum())
# Out:
# Número de duplicados después de limpiar: 0

# %%
Pulmo2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 246013 entries, 0 to 246021
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      246013 non-null  object
#  1   Sex                        246013 non-null  object
#  2   GeneralHealth              246013 non-null  object
#  3   PhysicalHealthDays         246013 non-null  float64
#  4   MentalHealthDays           246013 non-null  float64
#  5   LastCheckupTime            246013 non-null  object
#  6   PhysicalActivities         246013 non-null  object
#  7   SleepHours                 246013 non-null  float64
#  8   RemovedTeeth               246013 non-null  object
#  9   HadHeartAttack             246013 non-null  object
#  10  HadAngina                  246013 non-null  object
#  11  HadStroke                  246013 non-null  object
#  12  HadAsthma                  246013 non-null  object
# ...

# %%
# Valores únicos en la columna 'State'
print(Pulmo2["State"].unique())
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming' 'Guam' 'Puerto Rico'
#  'Virgin Islands']

# %%
# One-Hot Encoding para State
Pulmo2 = pd.get_dummies(Pulmo2, columns=["State"], prefix="State")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="State_").columns] = Pulmo2.filter(like="State_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="State_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# State_Alabama [1 0] int64
# State_Alaska [0 1] int64
# State_Arizona [0 1] int64
# State_Arkansas [0 1] int64
# State_California [0 1] int64
# State_Colorado [0 1] int64
# State_Connecticut [0 1] int64
# State_Delaware [0 1] int64
# State_District of Columbia [0 1] int64
# State_Florida [0 1] int64
# State_Georgia [0 1] int64
# State_Guam [0 1] int64
# State_Hawaii [0 1] int64
# State_Idaho [0 1] int64
# State_Illinois [0 1] int64
# State_Indiana [0 1] int64
# State_Iowa [0 1] int64
# State_Kansas [0 1] int64
# State_Kentucky [0 1] int64
# State_Louisiana [0 1] int64
# State_Maine [0 1] int64
# State_Maryland [0 1] int64
# State_Massachusetts [0 1] int64
# State_Michigan [0 1] int64
# State_Minnesota [0 1] int64
# State_Mississippi [0 1] int64
# State_Missouri [0 1] int64
# State_Montana [0 1] int64
# State_Nebraska [0 1] int64
# State_Nevada [0 1] int64
# State_New Hampshire [0 1] int64
# State_New Jersey [0 1] int64
# State_New Mexico [0 1] int64
# State_New York [0 1] int64
# ...

# %%
# Valores únicos en la columna 'sex'
print(Pulmo2["Sex"].unique())
# Out:
# ['Female' 'Male']

# %%
# Normalización de la variable 'Sex'
Pulmo2["Sex"] = Pulmo2["Sex"].map({
    "Male": 1,    # 1 corresponde a masculino
    "Female": 0   # 0 corresponde a femenino
})

# Verificar los primeros registros
print(Pulmo2["Sex"].head())
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: Sex, dtype: int64

# %%
# Valores únicos en la columna 'GeneralHealth'
print(Pulmo2["GeneralHealth"].unique())
# Out:
# ['Very good' 'Fair' 'Good' 'Excellent' 'Poor']

# %%
# One-Hot Encoding para GeneralHealth
Pulmo2 = pd.get_dummies(Pulmo2, columns=["GeneralHealth"], prefix="GeneralHealth")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="GeneralHealth_").columns] = Pulmo2.filter(like="GeneralHealth_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="GeneralHealth_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# GeneralHealth_Excellent [0 1] int64
# GeneralHealth_Fair [0 1] int64
# GeneralHealth_Good [0 1] int64
# GeneralHealth_Poor [0 1] int64
# GeneralHealth_Very good [1 0] int64

# %%
# Valores únicos en la columna 'LastCheckupTime'
print(Pulmo2["LastCheckupTime"].unique())
# Out:
# ['Within past year (anytime less than 12 months ago)'
#  '5 or more years ago'
#  'Within past 2 years (1 year but less than 2 years ago)'
#  'Within past 5 years (2 years but less than 5 years ago)']

# %%
# One-Hot Encoding para LastCheckupTime
Pulmo2 = pd.get_dummies(Pulmo2, columns=["LastCheckupTime"], prefix="LastCheckupTime")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="LastCheckupTime_").columns] = Pulmo2.filter(like="LastCheckupTime_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="LastCheckupTime_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# LastCheckupTime_5 or more years ago [0 1] int64
# LastCheckupTime_Within past 2 years (1 year but less than 2 years ago) [0 1] int64
# LastCheckupTime_Within past 5 years (2 years but less than 5 years ago) [0 1] int64
# LastCheckupTime_Within past year (anytime less than 12 months ago) [1 0] int64

# %%
# Valores únicos en la columna 'PhysicalActivities'
print(Pulmo2["PhysicalActivities"].unique())
# Out:
# ['Yes' 'No']

# %%
# One-Hot Encoding para PhysicalActivities
Pulmo2 = pd.get_dummies(Pulmo2, columns=["PhysicalActivities"], prefix="PhysicalActivities")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="PhysicalActivities_").columns] = Pulmo2.filter(like="PhysicalActivities_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="PhysicalActivities_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# PhysicalActivities_No [0 1] int64
# PhysicalActivities_Yes [1 0] int64

# %%
# Valores únicos en la columna 'RemovedTeeth'
print(Pulmo2["RemovedTeeth"].unique())
# Out:
# ['None of them' '6 or more, but not all' '1 to 5' 'All']

# %%
# One-Hot Encoding para RemovedTeeth
Pulmo2 = pd.get_dummies(Pulmo2, columns=["RemovedTeeth"], prefix="RemovedTeeth")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="RemovedTeeth_").columns] = Pulmo2.filter(like="RemovedTeeth_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="RemovedTeeth_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# RemovedTeeth_1 to 5 [0 1] int64
# RemovedTeeth_6 or more, but not all [0 1] int64
# RemovedTeeth_All [0 1] int64
# RemovedTeeth_None of them [1 0] int64

# %%
# Valores únicos en la columna 'HadHeartAttack'
print(Pulmo2["HadHeartAttack"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HadHeartAttack
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadHeartAttack"], prefix="HadHeartAttack")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadHeartAttack_").columns] = Pulmo2.filter(like="HadHeartAttack_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadHeartAttack_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadHeartAttack_No [1 0] int64
# HadHeartAttack_Yes [0 1] int64

# %%
# Valores únicos en la columna 'HadAngina'
print(Pulmo2["HadAngina"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HadAngina
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadAngina"], prefix="HadAngina")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadAngina_").columns] = Pulmo2.filter(like="HadAngina_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadAngina_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadAngina_No [1 0] int64
# HadAngina_Yes [0 1] int64

# %%
# Valores únicos en la columna 'HadStroke'
print(Pulmo2["HadStroke"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HadStroke
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadStroke"], prefix="HadStroke")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadStroke_").columns] = Pulmo2.filter(like="HadStroke_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadStroke_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadStroke_No [1 0] int64
# HadStroke_Yes [0 1] int64

# %%
# Valores únicos en la columna 'HadAsthma'
print(Pulmo2["HadAsthma"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HadAsthma
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadAsthma"], prefix="HadAsthma")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadAsthma_").columns] = Pulmo2.filter(like="HadAsthma_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadAsthma_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadAsthma_No [1 0] int64
# HadAsthma_Yes [0 1] int64

# %%
# Valores únicos en la columna 'HadSkinCancer'
print(Pulmo2["HadSkinCancer"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HadSkinCancer
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadSkinCancer"], prefix="HadSkinCancer")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadSkinCancer_").columns] = Pulmo2.filter(like="HadSkinCancer_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadSkinCancer_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadSkinCancer_No [1 0] int64
# HadSkinCancer_Yes [0 1] int64

# %%
# Valores únicos en la columna 'HadCOPD'
print(Pulmo2["HadCOPD"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HadCOPD
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadCOPD"], prefix="HadCOPD")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadCOPD_").columns] = Pulmo2.filter(like="HadCOPD_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadCOPD_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadCOPD_No [1 0] int64
# HadCOPD_Yes [0 1] int64

# %%
# Valores únicos en la columna 'HadDepressiveDisorder'
print(Pulmo2["HadDepressiveDisorder"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HadDepressiveDisorder
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadDepressiveDisorder"], prefix="HadDepressiveDisorder")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadDepressiveDisorder_").columns] = Pulmo2.filter(like="HadDepressiveDisorder_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadDepressiveDisorder_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadDepressiveDisorder_No [1 0] int64
# HadDepressiveDisorder_Yes [0 1] int64

# %%
# Valores únicos en la columna 'HadKidneyDisease'
print(Pulmo2["HadKidneyDisease"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HadKidneyDisease
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadKidneyDisease"], prefix="HadKidneyDisease")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadKidneyDisease_").columns] = Pulmo2.filter(like="HadKidneyDisease_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadKidneyDisease_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadKidneyDisease_No [1 0] int64
# HadKidneyDisease_Yes [0 1] int64

# %%
# Valores únicos en la columna 'HadArthritis'
print(Pulmo2["HadArthritis"].unique())
# Out:
# ['Yes' 'No']

# %%
# One-Hot Encoding para HadArthritis
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadArthritis"], prefix="HadArthritis")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadArthritis_").columns] = Pulmo2.filter(like="HadArthritis_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadArthritis_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadArthritis_No [0 1] int64
# HadArthritis_Yes [1 0] int64

# %%
# Valores únicos en la columna 'HadDiabetes'
print(Pulmo2["HadDiabetes"].unique())
# Out:
# ['No' 'Yes' 'Yes, but only during pregnancy (female)'
#  'No, pre-diabetes or borderline diabetes']

# %%
# One-Hot Encoding para HadDiabetes
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HadDiabetes"], prefix="HadDiabetes")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HadDiabetes_").columns] = Pulmo2.filter(like="HadDiabetes_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HadDiabetes_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HadDiabetes_No [1 0] int64
# HadDiabetes_No, pre-diabetes or borderline diabetes [0 1] int64
# HadDiabetes_Yes [0 1] int64
# HadDiabetes_Yes, but only during pregnancy (female) [0 1] int64

# %%
# Valores únicos en la columna 'DeafOrHardOfHearing'
print(Pulmo2["DeafOrHardOfHearing"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para DeafOrHardOfHearing
Pulmo2 = pd.get_dummies(Pulmo2, columns=["DeafOrHardOfHearing"], prefix="DeafOrHardOfHearing")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="DeafOrHardOfHearing_").columns] = Pulmo2.filter(like="DeafOrHardOfHearing_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="DeafOrHardOfHearing_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# DeafOrHardOfHearing_No [1 0] int64
# DeafOrHardOfHearing_Yes [0 1] int64

# %%
# Valores únicos en la columna 'BlindOrVisionDifficulty'
print(Pulmo2["BlindOrVisionDifficulty"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para BlindOrVisionDifficulty
Pulmo2 = pd.get_dummies(Pulmo2, columns=["BlindOrVisionDifficulty"], prefix="BlindOrVisionDifficulty")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="BlindOrVisionDifficulty_").columns] = Pulmo2.filter(like="BlindOrVisionDifficulty_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="BlindOrVisionDifficulty_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# BlindOrVisionDifficulty_No [1 0] int64
# BlindOrVisionDifficulty_Yes [0 1] int64

# %%
# Valores únicos en la columna 'DifficultyConcentrating'
print(Pulmo2["DifficultyConcentrating"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para DifficultyConcentrating
Pulmo2 = pd.get_dummies(Pulmo2, columns=["DifficultyConcentrating"], prefix="DifficultyConcentrating")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="DifficultyConcentrating_").columns] = Pulmo2.filter(like="DifficultyConcentrating_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="DifficultyConcentrating_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# DifficultyConcentrating_No [1 0] int64
# DifficultyConcentrating_Yes [0 1] int64

# %%
# Valores únicos en la columna 'DifficultyWalking'
print(Pulmo2["DifficultyWalking"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para DifficultyWalking
Pulmo2 = pd.get_dummies(Pulmo2, columns=["DifficultyWalking"], prefix="DifficultyWalking")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="DifficultyWalking_").columns] = Pulmo2.filter(like="DifficultyWalking_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="DifficultyWalking_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# DifficultyWalking_No [1 0] int64
# DifficultyWalking_Yes [0 1] int64

# %%
# Valores únicos en la columna 'DifficultyDressingBathing'
print(Pulmo2["DifficultyDressingBathing"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para DifficultyDressingBathing
Pulmo2 = pd.get_dummies(Pulmo2, columns=["DifficultyDressingBathing"], prefix="DifficultyDressingBathing")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="DifficultyDressingBathing_").columns] = Pulmo2.filter(like="DifficultyDressingBathing_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="DifficultyDressingBathing_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# DifficultyDressingBathing_No [1 0] int64
# DifficultyDressingBathing_Yes [0 1] int64

# %%
# Valores únicos en la columna 'DifficultyErrands'
print(Pulmo2["DifficultyErrands"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para DifficultyErrands
Pulmo2 = pd.get_dummies(Pulmo2, columns=["DifficultyErrands"], prefix="DifficultyErrands")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="DifficultyErrands_").columns] = Pulmo2.filter(like="DifficultyErrands_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="DifficultyErrands_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# DifficultyErrands_No [1 0] int64
# DifficultyErrands_Yes [0 1] int64

# %%
# Valores únicos en la columna 'SmokerStatus'
print(Pulmo2["SmokerStatus"].unique())
# Out:
# ['Former smoker' 'Never smoked' 'Current smoker - now smokes every day'
#  'Current smoker - now smokes some days']

# %%
# One-Hot Encoding para SmokerStatus
Pulmo2 = pd.get_dummies(Pulmo2, columns=["SmokerStatus"], prefix="SmokerStatus")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="SmokerStatus_").columns] = Pulmo2.filter(like="SmokerStatus_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="SmokerStatus_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# SmokerStatus_Current smoker - now smokes every day [0 1] int64
# SmokerStatus_Current smoker - now smokes some days [0 1] int64
# SmokerStatus_Former smoker [1 0] int64
# SmokerStatus_Never smoked [0 1] int64

# %%
# Valores únicos en la columna 'ECigaretteUsage'
print(Pulmo2["ECigaretteUsage"].unique())
# Out:
# ['Never used e-cigarettes in my entire life' 'Use them some days'
#  'Not at all (right now)' 'Use them every day']

# %%
# One-Hot Encoding para ECigaretteUsage
Pulmo2 = pd.get_dummies(Pulmo2, columns=["ECigaretteUsage"], prefix="ECigaretteUsage")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="ECigaretteUsage_").columns] = Pulmo2.filter(like="ECigaretteUsage_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="ECigaretteUsage_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# ECigaretteUsage_Never used e-cigarettes in my entire life [1 0] int64
# ECigaretteUsage_Not at all (right now) [0 1] int64
# ECigaretteUsage_Use them every day [0 1] int64
# ECigaretteUsage_Use them some days [0 1] int64

# %%
# Valores únicos en la columna 'ChestScan'
print(Pulmo2["ChestScan"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para ChestScan
Pulmo2 = pd.get_dummies(Pulmo2, columns=["ChestScan"], prefix="ChestScan")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="ChestScan_").columns] = Pulmo2.filter(like="ChestScan_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="ChestScan_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# ChestScan_No [1 0] int64
# ChestScan_Yes [0 1] int64

# %%
# Valores únicos en la columna 'RaceEthnicityCategory'
print(Pulmo2["RaceEthnicityCategory"].unique())
# Out:
# ['White only, Non-Hispanic' 'Black only, Non-Hispanic'
#  'Other race only, Non-Hispanic' 'Multiracial, Non-Hispanic' 'Hispanic']

# %%
# One-Hot Encoding para RaceEthnicityCategory
Pulmo2 = pd.get_dummies(Pulmo2, columns=["RaceEthnicityCategory"], prefix="RaceEthnicityCategory")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="RaceEthnicityCategory_").columns] = Pulmo2.filter(like="RaceEthnicityCategory_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="RaceEthnicityCategory_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# RaceEthnicityCategory_Black only, Non-Hispanic [0 1] int64
# RaceEthnicityCategory_Hispanic [0 1] int64
# RaceEthnicityCategory_Multiracial, Non-Hispanic [0 1] int64
# RaceEthnicityCategory_Other race only, Non-Hispanic [0 1] int64
# RaceEthnicityCategory_White only, Non-Hispanic [1 0] int64

# %%
# Valores únicos en la columna 'AgeCategory'
print(Pulmo2["AgeCategory"].unique())
# Out:
# ['Age 65 to 69' 'Age 70 to 74' 'Age 75 to 79' 'Age 80 or older'
#  'Age 50 to 54' 'Age 40 to 44' 'Age 60 to 64' 'Age 55 to 59'
#  'Age 45 to 49' 'Age 35 to 39' 'Age 25 to 29' 'Age 30 to 34'
#  'Age 18 to 24']

# %%
# One-Hot Encoding para AgeCategory
Pulmo2 = pd.get_dummies(Pulmo2, columns=["AgeCategory"], prefix="AgeCategory")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="AgeCategory_").columns] = Pulmo2.filter(like="AgeCategory_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="AgeCategory_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# AgeCategory_Age 18 to 24 [0 1] int64
# AgeCategory_Age 25 to 29 [0 1] int64
# AgeCategory_Age 30 to 34 [0 1] int64
# AgeCategory_Age 35 to 39 [0 1] int64
# AgeCategory_Age 40 to 44 [0 1] int64
# AgeCategory_Age 45 to 49 [0 1] int64
# AgeCategory_Age 50 to 54 [0 1] int64
# AgeCategory_Age 55 to 59 [0 1] int64
# AgeCategory_Age 60 to 64 [0 1] int64
# AgeCategory_Age 65 to 69 [1 0] int64
# AgeCategory_Age 70 to 74 [0 1] int64
# AgeCategory_Age 75 to 79 [0 1] int64
# AgeCategory_Age 80 or older [0 1] int64

# %%
# Valores únicos en la columna 'AlcoholDrinkers'
print(Pulmo2["AlcoholDrinkers"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para AlcoholDrinkers
Pulmo2 = pd.get_dummies(Pulmo2, columns=["AlcoholDrinkers"], prefix="AlcoholDrinkers")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="AlcoholDrinkers_").columns] = Pulmo2.filter(like="AlcoholDrinkers_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="AlcoholDrinkers_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# AlcoholDrinkers_No [1 0] int64
# AlcoholDrinkers_Yes [0 1] int64

# %%
# Valores únicos en la columna 'HIVTesting'
print(Pulmo2["HIVTesting"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HIVTesting
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HIVTesting"], prefix="HIVTesting")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HIVTesting_").columns] = Pulmo2.filter(like="HIVTesting_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HIVTesting_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HIVTesting_No [1 0] int64
# HIVTesting_Yes [0 1] int64

# %%
# Valores únicos en la columna 'FluVaxLast12'
print(Pulmo2["FluVaxLast12"].unique())
# Out:
# ['Yes' 'No']

# %%
# One-Hot Encoding para FluVaxLast12
Pulmo2 = pd.get_dummies(Pulmo2, columns=["FluVaxLast12"], prefix="FluVaxLast12")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="FluVaxLast12_").columns] = Pulmo2.filter(like="FluVaxLast12_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="FluVaxLast12_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# FluVaxLast12_No [0 1] int64
# FluVaxLast12_Yes [1 0] int64

# %%
# Valores únicos en la columna 'PneumoVaxEver'
print(Pulmo2["PneumoVaxEver"].unique())
# Out:
# ['Yes' 'No']

# %%
# One-Hot Encoding para PneumoVaxEver
Pulmo2 = pd.get_dummies(Pulmo2, columns=["PneumoVaxEver"], prefix="PneumoVaxEver")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="PneumoVaxEver_").columns] = Pulmo2.filter(like="PneumoVaxEver_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="PneumoVaxEver_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# PneumoVaxEver_No [0 1] int64
# PneumoVaxEver_Yes [1 0] int64

# %%
# Valores únicos en la columna 'TetanusLast10Tdap'
print(Pulmo2["TetanusLast10Tdap"].unique())
# Out:
# ['Yes, received Tdap' 'Yes, received tetanus shot but not sure what type'
#  'No, did not receive any tetanus shot in the past 10 years'
#  'Yes, received tetanus shot, but not Tdap']

# %%
# One-Hot Encoding para TetanusLast10Tdap
Pulmo2 = pd.get_dummies(Pulmo2, columns=["TetanusLast10Tdap"], prefix="TetanusLast10Tdap")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="TetanusLast10Tdap_").columns] = Pulmo2.filter(like="TetanusLast10Tdap_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="TetanusLast10Tdap_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# TetanusLast10Tdap_No, did not receive any tetanus shot in the past 10 years [0 1] int64
# TetanusLast10Tdap_Yes, received Tdap [1 0] int64
# TetanusLast10Tdap_Yes, received tetanus shot but not sure what type [0 1] int64
# TetanusLast10Tdap_Yes, received tetanus shot, but not Tdap [0 1] int64

# %%
# Valores únicos en la columna 'HighRiskLastYear'
print(Pulmo2["HighRiskLastYear"].unique())
# Out:
# ['No' 'Yes']

# %%
# One-Hot Encoding para HighRiskLastYear
Pulmo2 = pd.get_dummies(Pulmo2, columns=["HighRiskLastYear"], prefix="HighRiskLastYear")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="HighRiskLastYear_").columns] = Pulmo2.filter(like="HighRiskLastYear_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="HighRiskLastYear_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# HighRiskLastYear_No [1 0] int64
# HighRiskLastYear_Yes [0 1] int64

# %%
# Valores únicos en la columna 'CovidPos'
print(Pulmo2["CovidPos"].unique())
# Out:
# ['No' 'Yes'
#  'Tested positive using home test without a health professional']

# %%
# One-Hot Encoding para CovidPos
Pulmo2 = pd.get_dummies(Pulmo2, columns=["CovidPos"], prefix="CovidPos")

# Convertir las nuevas columnas a enteros (0 y 1)
Pulmo2[Pulmo2.filter(like="CovidPos_").columns] = Pulmo2.filter(like="CovidPos_").astype(int)

# Verificar resultado
for col in Pulmo2.filter(like="CovidPos_").columns:
    print(col, Pulmo2[col].unique(), Pulmo2[col].dtype)
# Out:
# CovidPos_No [1 0] int64
# CovidPos_Tested positive using home test without a health professional [0 1] int64
# CovidPos_Yes [0 1] int64

# %%
Pulmo2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 246013 entries, 0 to 246021
# Columns: 155 entries, Sex to CovidPos_Yes
# dtypes: float64(6), int64(149)
# memory usage: 292.8 MB

# %%
# Lista de todas las columnas (variables) del DataFrame
print(Pulmo2.columns)
# Out:
# Index(['Sex', 'PhysicalHealthDays', 'MentalHealthDays', 'SleepHours',
#        'HeightInMeters', 'WeightInKilograms', 'BMI', 'State_Alabama',
#        'State_Alaska', 'State_Arizona',
#        ...
#        'PneumoVaxEver_Yes',
#        'TetanusLast10Tdap_No, did not receive any tetanus shot in the past 10 years',
#        'TetanusLast10Tdap_Yes, received Tdap',
#        'TetanusLast10Tdap_Yes, received tetanus shot but not sure what type',
#        'TetanusLast10Tdap_Yes, received tetanus shot, but not Tdap',
#        'HighRiskLastYear_No', 'HighRiskLastYear_Yes', 'CovidPos_No',
#        'CovidPos_Tested positive using home test without a health professional',
#        'CovidPos_Yes'],
#       dtype='object', length=155)

# %%
# Ver el tipo de dato de cada columna
print(Pulmo2.dtypes)
# Out:
# Sex                                                                         int64
# PhysicalHealthDays                                                        float64
# MentalHealthDays                                                          float64
# SleepHours                                                                float64
# HeightInMeters                                                            float64
#                                                                            ...
# HighRiskLastYear_No                                                         int64
# HighRiskLastYear_Yes                                                        int64
# CovidPos_No                                                                 int64
# CovidPos_Tested positive using home test without a health professional      int64
# CovidPos_Yes                                                                int64
# Length: 155, dtype: object

# %%
# Guardar Pulmo1 en un archivo CSV
Pulmo2.to_csv("Pulmo2.csv", index=False)

print("Archivo Pulmo2.csv descargado correctamente")
# Out:
# Archivo Pulmo2.csv descargado correctamente

# %% [markdown]
# ## Descripción de Columnas del DataFrame `Pulmo2`
#
# | Columna                 | Descripción                                                                 |
# | :---------------------- | :-------------------------------------------------------------------------- |
# | State                   | Estado de residencia del encuestado.                                      |
# | Sex                     | Género del encuestado.                                                      |
# | GeneralHealth           | Salud general percibida del encuestado.                                     |
# | PhysicalHealthDays      | Número de días durante los últimos 30 en que la salud física no fue buena. |
# | MentalHealthDays        | Número de días durante los últimos 30 en que la salud mental no fue buena. |
# | LastCheckupTime         | Tiempo transcurrido desde el último chequeo médico.                       |
# | PhysicalActivities      | Si el encuestado realizó actividades físicas en los últimos 30 días.       |
# | SleepHours              | Horas de sueño promedio.                                                  |
# | RemovedTeeth            | Número de dientes extraídos.                                                |
# | HadHeartAttack          | Si el encuestado ha tenido un ataque al corazón.                          |
# | HadAngina               | Si el encuestado ha tenido angina de pecho.                               |
# | HadStroke               | Si el encuestado ha tenido un derrame cerebral.                           |
# | HadAsthma               | Si el encuestado ha tenido asma.                                          |
# | HadSkinCancer           | Si el encuestado ha tenido cáncer de piel.                                |
# | HadCOPD                 | Si el encuestado ha tenido EPOC (Enfermedad Pulmonar Obstructiva Crónica).|
# | HadDepressiveDisorder   | Si el encuestado ha tenido un trastorno depresivo.                        |
# | HadKidneyDisease        | Si el encuestado ha tenido enfermedad renal.                              |
# | HadArthritis            | Si el encuestado ha tenido artritis.                                      |
# | HadDiabetes             | Si el encuestado ha tenido diabetes.                                      |
# | DeafOrHardOfHearing     | Si el encuestado es sordo o tiene dificultad para oír.                   |
# | BlindOrVisionDifficulty | Si el encuestado es ciego o tiene dificultad visual.                     |
# | DifficultyConcentrating | Si el encuestado tiene dificultad para concentrarse.                     |
# | DifficultyWalking       | Si el encuestado tiene dificultad para caminar.                          |
# | DifficultyDressingBathing| Si el encuestado tiene dificultad para vestirse o bañarse.               |
# | DifficultyErrands       | Si el encuestado tiene dificultad para hacer recados.                    |
# | SmokerStatus            | Estado de fumador del encuestado.                                         |
# | ECigaretteUsage         | Uso de cigarrillos electrónicos.                                          |
# | ChestScan               | Si se ha realizado una exploración de tórax.                                |
# | RaceEthnicityCategory   | Categoría de raza/etnia del encuestado.                                   |
# | AgeCategory             | Categoría de edad del encuestado.                                         |
# | HeightInMeters          | Altura del encuestado en metros.                                          |
# | WeightInKilograms       | Peso del encuestado en kilogramos.                                        |
# | BMI                     | Índice de Masa Corporal (IMC) del encuestado.                             |
# | AlcoholDrinkers         | Si el encuestado es bebedor de alcohol.                                   |
# | HIVTesting              | Si el encuestado se ha realizado una prueba de VIH.                       |
# | FluVaxLast12            | Si el encuestado recibió la vacuna contra la gripe en los últimos 12 meses.|
# | PneumoVaxEver           | Si el encuestado recibió la vacuna antineumocócica alguna vez.           |
# | TetanusLast10Tdap       | Si el encuestado recibió la vacuna contra el tétanos en los últimos 10 años.|
# | HighRiskLastYear        | Si el encuestado ha sido considerado de alto riesgo en el último año.     |
# | CovidPos                | Resultado de la prueba de COVID-19.                                       |
